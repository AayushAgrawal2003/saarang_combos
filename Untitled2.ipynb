# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel("./ONLINE ENGAGEMENT TASK 1.xlsx")

# %%
df.head()
# Out:
#                writing         Unnamed: 1             word game  \
# 0                  NaN                NaN                   NaN
# 1  English Slam Poetry  Hindi Slam Poetry              Scrabble
# 2    Atharva Bhatnagar    Piyush Pancholi        Parichay Gupta
# 3            Abhilasha      Jainam Khatri  Pothula Meghana Raaj
# 4    Nishtha Taktewale  Nikita Srivastava           Anshul Buxy
#
#         Unnamed: 3         Unnamed: 4                 Quiz  \
# 0              NaN                NaN                  NaN
# 1  Cryptic Crossie  Sacred Word Games         General Quiz
# 2   Parichay Gupta     Parichay Gupta         Aayush Gahan
# 3     Anup Preeyam     Neha Kolukonda    Vedanta Mohapatra
# 4       Gnan Vikas     Malla Likhitha  Aditya Balakrishnan
#
#             Unnamed: 6           Unnamed: 7         Unnamed: 8  \
# 0                  NaN                  NaN                NaN
# 1           SciBizTech                 MELA             Sports
# ...

# %%
current_series = pd.Series(['t'])
db = pd.DataFrame()
titles = [0]
for i in df:
    if i.split()[0] != "Unnamed:":
        titles.append(i)
        current_series.reset_index(drop=True)
        db = pd.concat([db,current_series],axis =1)
        #print(current_series)
        current_series = pd.Series()
        current_series = pd.concat([current_series,df[i]],axis = 0)
        current_series = current_series.reset_index(drop=True)        
    if i.split()[0] == "Unnamed:":
        current_series = pd.concat([current_series,df[i]],axis = 0)
        current_series = current_series.reset_index(drop=True)
        
db = pd.concat([db,current_series],axis =1)
# Out:
# /var/folders/jw/644649297gd0_6hzy4hf6yl00000gn/T/ipykernel_17284/851518082.py:10: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   current_series = pd.Series()

# %%
db.columns = titles
db = db.drop([0],axis =1)
db = db.drop([0],axis =0)

# %%
db
# Out:
#                  writing             word game                 Quiz  \
# 1    English Slam Poetry              Scrabble         General Quiz
# 2      Atharva Bhatnagar        Parichay Gupta         Aayush Gahan
# 3              Abhilasha  Pothula Meghana Raaj    Vedanta Mohapatra
# 4      Nishtha Taktewale           Anshul Buxy  Aditya Balakrishnan
# 5         Shalvika Alice         Prasad Kukade     Hrushikesh Joshi
# ..                   ...                   ...                  ...
# 745                  NaN                   NaN                  NaN
# 746                  NaN                   NaN                  NaN
# 747                  NaN                   NaN                  NaN
# 748                  NaN                   NaN                  NaN
# 749                  NaN                   NaN                  NaN
#
#              Oratory             Music              Fashion  \
# 1               STEW  Band Competition         Fashion Show
# ...
